# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import plotly.express as px

# %%
#Dataset 
confirmed_case_file = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv'
death_case_file = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv'
recovered_case_file= 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv'
country_wise_case_file = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/web-data/data/cases_country.csv'

# %%
#Fatch Dataset files into data frame
confirmed_df = pd.read_csv(confirmed_case_file)
print(confirmed_df.shape)
confirmed_df.head()
# Out:
# (266, 155)
#   Province/State Country/Region      Lat  ...  6/18/20  6/19/20  6/20/20
# 0            NaN    Afghanistan  33.0000  ...    27532    27878    28424
# 1            NaN        Albania  41.1533  ...     1788     1838     1891
# 2            NaN        Algeria  28.0339  ...    11385    11504    11631
# 3            NaN        Andorra  42.5063  ...      855      855      855
# 4            NaN         Angola -11.2027  ...      166      172      176
#
# [5 rows x 155 columns]

# %%
#Fatch Dataset files into data frame
death_df = pd.read_csv(death_case_file)
print(death_df.shape)
death_df.head()
# Out:
# (266, 155)
#   Province/State Country/Region      Lat  ...  6/18/20  6/19/20  6/20/20
# 0            NaN    Afghanistan  33.0000  ...      546      548      569
# 1            NaN        Albania  41.1533  ...       39       42       43
# 2            NaN        Algeria  28.0339  ...      811      825      837
# 3            NaN        Andorra  42.5063  ...       52       52       52
# 4            NaN         Angola -11.2027  ...        8        8        9
#
# [5 rows x 155 columns]

# %%
#Fatch Dataset files into data frame
recovered_df = pd.read_csv(recovered_case_file)
print(recovered_df.shape)
recovered_df.head()
# Out:
# (253, 155)
#   Province/State Country/Region      Lat  ...  6/18/20  6/19/20  6/20/20
# 0            NaN    Afghanistan  33.0000  ...     7660     7962     8292
# 1            NaN        Albania  41.1533  ...     1086     1114     1126
# 2            NaN        Algeria  28.0339  ...     8078     8196     8324
# 3            NaN        Andorra  42.5063  ...      792      792      792
# 4            NaN         Angola -11.2027  ...       64       66       66
#
# [5 rows x 155 columns]

# %%
#Fatch Dataset files into data frame
country_df = pd.read_csv(country_wise_case_file)
print(country_df.shape)
country_df.head()
# Out:
# (188, 14)
#   Country_Region          Last_Update      Lat  ...  Mortality_Rate  UID  ISO3
# 0      Australia  2020-06-21 15:33:21 -25.0000  ...        1.367109   36   AUS
# 1        Austria  2020-06-21 15:33:21  47.5162  ...        3.979009   40   AUT
# 2         Canada  2020-06-21 15:33:21  60.0010  ...        8.238454  124   CAN
# 3          China  2020-06-21 15:33:21  30.5928  ...        5.486500  156   CHN
# 4        Denmark  2020-06-21 15:33:21  56.2639  ...        4.765309  208   DNK
#
# [5 rows x 14 columns]

# %%
#Check data for Canada
confirmed_df[confirmed_df["Country/Region"]=="Canada"]
# Out:
#                 Province/State Country/Region  ...  6/19/20  6/20/20
# 35                     Alberta         Canada  ...     7625     7673
# 36            British Columbia         Canada  ...     2790     2790
# 37              Grand Princess         Canada  ...       13       13
# 38                    Manitoba         Canada  ...      311      313
# 39               New Brunswick         Canada  ...      164      164
# 40   Newfoundland and Labrador         Canada  ...      261      261
# 41                 Nova Scotia         Canada  ...     1061     1061
# 42                     Ontario         Canada  ...    34780    35044
# 43        Prince Edward Island         Canada  ...       27       27
# 44                      Quebec         Canada  ...    54550    54674
# 45                Saskatchewan         Canada  ...      716      726
# 231           Diamond Princess         Canada  ...        0        0
# 244      Northwest Territories         Canada  ...        5        5
# 245                      Yukon         Canada  ...       11       11
#
# [14 rows x 155 columns]

# %%
confirmed_df[confirmed_df["Country/Region"]=="India"]
# Out:
#     Province/State Country/Region   Lat  ...  6/18/20  6/19/20  6/20/20
# 131            NaN          India  21.0  ...   380532   395048   410451
#
# [1 rows x 155 columns]

# %%
#Total number of Countries
confirmed_df["Country/Region"].nunique()
# Out:
# 188

# %%
#Replacing null values
confirmed_df = confirmed_df.replace(np.nan,'', regex=True)
confirmed_df.head()
# Out:
#   Province/State Country/Region      Lat  ...  6/18/20  6/19/20  6/20/20
# 0                   Afghanistan  33.0000  ...    27532    27878    28424
# 1                       Albania  41.1533  ...     1788     1838     1891
# 2                       Algeria  28.0339  ...    11385    11504    11631
# 3                       Andorra  42.5063  ...      855      855      855
# 4                        Angola -11.2027  ...      166      172      176
#
# [5 rows x 155 columns]

# %%
#Replacing null values
death_df = death_df.replace(np.nan,'',regex = True)
death_df.head()
# Out:
#   Province/State Country/Region      Lat  ...  6/18/20  6/19/20  6/20/20
# 0                   Afghanistan  33.0000  ...      546      548      569
# 1                       Albania  41.1533  ...       39       42       43
# 2                       Algeria  28.0339  ...      811      825      837
# 3                       Andorra  42.5063  ...       52       52       52
# 4                        Angola -11.2027  ...        8        8        9
#
# [5 rows x 155 columns]

# %%
#Replacing null values
recovered_df= recovered_df.replace(np.nan,'',regex = True)
recovered_df.head()
# Out:
#   Province/State Country/Region      Lat  ...  6/18/20  6/19/20  6/20/20
# 0                   Afghanistan  33.0000  ...     7660     7962     8292
# 1                       Albania  41.1533  ...     1086     1114     1126
# 2                       Algeria  28.0339  ...     8078     8196     8324
# 3                       Andorra  42.5063  ...      792      792      792
# 4                        Angola -11.2027  ...       64       66       66
#
# [5 rows x 155 columns]

# %%
#Replacing null values
country_df = country_df.replace(np.nan,'',regex = True)
country_df.head()
# Out:
#   Country_Region          Last_Update      Lat  ... Mortality_Rate  UID  ISO3
# 0      Australia  2020-06-21 15:33:21      -25  ...       1.367109   36   AUS
# 1        Austria  2020-06-21 15:33:21  47.5162  ...       3.979009   40   AUT
# 2         Canada  2020-06-21 15:33:21   60.001  ...       8.238454  124   CAN
# 3          China  2020-06-21 15:33:21  30.5928  ...       5.486500  156   CHN
# 4        Denmark  2020-06-21 15:33:21  56.2639  ...       4.765309  208   DNK
#
# [5 rows x 14 columns]

# %%
#Total Count of Cases
global_data = country_df.copy().drop(['Lat','Long_','Country_Region','Last_Update','ISO3','People_Hospitalized','People_Tested','UID','Mortality_Rate'],axis = 1)
global_summary = pd.DataFrame(global_data.sum()).transpose()
global_summary
# Out:
#    Confirmed    Deaths     Active
# 0  8827934.0  465051.0  3902036.0

# %%
#Total Count of confirmed case everyday
confirmed_total = confirmed_df.copy().drop(['Lat','Long','Country/Region','Province/State'],axis = 1)
confirmed_summary = confirmed_total.sum()
confirmed_summary
# Out:
# 1/22/20        555
# 1/23/20        654
# 1/24/20        941
# 1/25/20       1434
# 1/26/20       2118
#             ...
# 6/16/20    8173940
# 6/17/20    8349950
# 6/18/20    8488976
# 6/19/20    8664753
# 6/20/20    8791794
# Length: 151, dtype: int64

# %%
confirmed_to_fig = go.Figure(data=go.Scatter(x=confirmed_summary.index,y= confirmed_summary.values,mode='lines+markers'))
confirmed_to_fig.update_layout(title = 'Total number of cases everyday')
confirmed_to_fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="587fcfbf-36ac-4161-aed7-6347ff00d722" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("587fcfbf-36ac-4161-aed7-6347ff00d722")) {
#                     Plotly.newPlot(
#                         '587fcfbf-36ac-4161-aed7-6347ff00d722',
#                         [{"mode": "lines+markers", "type": "scatter", "x": ["1/22/20", "1/23/20", "1/24/20", "1/25/20", "1/26/20", "1/27/20", "1/28/20", "1/29/20", "1/30/20", "1/31/20", "2/1/20", "2/2/20", "2/3/20", "2/4/20", "2/5/20", "2/6/20", "2/7/20", "2/8/20", "2/9/20", "2/10/20", "2/11/20", "2/12/20", "2/13/20", "2/14/20", "2/15/20", "2/16/20", "2/17/20", "2/18/20", "2/19/20", "2/20/20", "2/21/20", "2/22/20", "2/23/20", "2/24/20", "2/25/20", "2/26/20", "2/27/20", "2/28/20", "2/29/20", "3/1/20", "3/2/20", "3/3/20", "3/4/20", "3/5/20", "3/6/20", "3/7/20", "3/8/20", "3/9/20", "3/10/20", "3/11/20", "3/12/20", "3/13/20", "3/14/20", "3/15/20", "3/16/20", "3/17/20", "3/18/20", "3/19/20", "3/20/20", "3/21/20", "3/22/20", "3/23/20", "3/24/20", "3/25/20", "3/26/20", "3/27/20", "3/28/20", "3/29/20", "3/30/20", "3/31/20", "4/1/20", "4/2/20", "4/3/20", "4/4/20", "4/5/20", "4/6/20", "4/7/20", "4/8/20", "4/9/20", "4/10/20", "4/11/20", "4/12/20", "4/13/20", "4/14/20", "4/15/20", "4/16/20", "4/17/20", "4/18/20", "4/19/20", "4/20/20", "4/21/20", "4/22/20", "4/23/20", "4/24/20", "4/25/20", "4/26/20", "4/27/20", "4/28/20", "4/29/20", "4/30/20", "5/1/20", "5/2/20", "5/3/20", "5/4/20", "5/5/20", "5/6/20", "5/7/20", "5/8/20", "5/9/20", "5/10/20", "5/11/20", "5/12/20", "5/13/20", "5/14/20", "5/15/20", "5/16/20", "5/17/20", "5/18/20", "5/19/20", "5/20/20", "5/21/20", "5/22/20", "5/23/20", "5/24/20", "5/25/20", "5/26/20", "5/27/20", "5/28/20", "5/29/20", "5/30/20", "5/31/20", "6/1/20", "6/2/20", "6/3/20", "6/4/20", "6/5/20", "6/6/20", "6/7/20", "6/8/20", "6/9/20", "6/10/20", "6/11/20", "6/12/20", "6/13/20", "6/14/20", "6/15/20", "6/16/20", "6/17/20", "6/18/20", "6/19/20", "6/20/20"], "y": [555, 654, 941, 1434, 2118, 2927, 5578, 6166, 8234, 9927, 12038, 16787, 19881, 23892, 27635, 30794, 34391, 37120, 40150, 42762, 44802, 45221, 60368, 66885, 69030, 71224, 73258, 75136, 75639, 76197, 76819, 78572, 78958, 79525, 80372, 81346, 82704, 84070, 85967, 88325, 90262, 92795, 95075, 97844, 101761, 105782, 109754, 113536, 118375, 125704, 130909, 145204, 156283, 167022, 181452, 196917, 216161, 243084, 272698, 304844, 337597, 378381, 418569, 468155, 530138, 594178, 661544, 720695, 783580, 858317, 933905, 1014713, 1097193, 1177447, 1251123, 1322598, 1397537, 1481490, 1567423, 1659674, 1737813, 1836615, 1906692, 1977287, 2057584, 2153578, 2242537, 2316591, 2399451, 2472264, 2546905, 2622750, 2711635, 2799064, 2884420, 2958352, 3027215, 3101078, 3176596, 3261450, 3349915, 3432050, 3511157, 3587874, 3668635, 3760836, 3851895, 3945002, 4030363, 4108270, 4184838, 4268247, 4353211, 4451126, 4548549, 4641727, 4721968, 4810315, 4906193, 5005761, 5112366, 5220585, 5321022, 5417354, 5504324, 5599216, 5702113, 5820253, 5941938, 6070884, 6178860, 6275246, 6387849, 6519164, 6642853, 6776126, 6902650, 7015739, 7119355, 7242692, 7376333, 7514724, 7644260, 7778881, 7912426, 8034461, 8173940, 8349950, 8488976, 8664753, 8791794]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {" ...

# %%
#Calculate Active Cases=(Confirmed-Receovered-Deatch)
confirmed_total = confirmed_df.copy().drop(['Lat','Long','Country/Region','Province/State'],axis = 1).sum()

death_total = death_df.copy().drop(['Lat','Long','Country/Region','Province/State'],axis = 1).sum()

recovered_total = recovered_df.copy().drop(['Lat','Long','Country/Region','Province/State'],axis = 1).sum()

active_cases = pd.Series( data=[x1-x2-x3 for (x1,x2,x3) in zip(confirmed_total.values,death_total.values,recovered_total.values)], index=confirmed_total.index
)

# %%
active_cases_fig = go.Figure(data=go.Scatter(x=active_cases.index,y= active_cases.values,mode='lines+markers'))
active_cases_fig.update_layout(title = 'Total number of Active cases everyday')
active_cases_fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a34d43b1-bd81-42b5-9055-07df73de7124" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a34d43b1-bd81-42b5-9055-07df73de7124")) {
#                     Plotly.newPlot(
#                         'a34d43b1-bd81-42b5-9055-07df73de7124',
#                         [{"mode": "lines+markers", "type": "scatter", "x": ["1/22/20", "1/23/20", "1/24/20", "1/25/20", "1/26/20", "1/27/20", "1/28/20", "1/29/20", "1/30/20", "1/31/20", "2/1/20", "2/2/20", "2/3/20", "2/4/20", "2/5/20", "2/6/20", "2/7/20", "2/8/20", "2/9/20", "2/10/20", "2/11/20", "2/12/20", "2/13/20", "2/14/20", "2/15/20", "2/16/20", "2/17/20", "2/18/20", "2/19/20", "2/20/20", "2/21/20", "2/22/20", "2/23/20", "2/24/20", "2/25/20", "2/26/20", "2/27/20", "2/28/20", "2/29/20", "3/1/20", "3/2/20", "3/3/20", "3/4/20", "3/5/20", "3/6/20", "3/7/20", "3/8/20", "3/9/20", "3/10/20", "3/11/20", "3/12/20", "3/13/20", "3/14/20", "3/15/20", "3/16/20", "3/17/20", "3/18/20", "3/19/20", "3/20/20", "3/21/20", "3/22/20", "3/23/20", "3/24/20", "3/25/20", "3/26/20", "3/27/20", "3/28/20", "3/29/20", "3/30/20", "3/31/20", "4/1/20", "4/2/20", "4/3/20", "4/4/20", "4/5/20", "4/6/20", "4/7/20", "4/8/20", "4/9/20", "4/10/20", "4/11/20", "4/12/20", "4/13/20", "4/14/20", "4/15/20", "4/16/20", "4/17/20", "4/18/20", "4/19/20", "4/20/20", "4/21/20", "4/22/20", "4/23/20", "4/24/20", "4/25/20", "4/26/20", "4/27/20", "4/28/20", "4/29/20", "4/30/20", "5/1/20", "5/2/20", "5/3/20", "5/4/20", "5/5/20", "5/6/20", "5/7/20", "5/8/20", "5/9/20", "5/10/20", "5/11/20", "5/12/20", "5/13/20", "5/14/20", "5/15/20", "5/16/20", "5/17/20", "5/18/20", "5/19/20", "5/20/20", "5/21/20", "5/22/20", "5/23/20", "5/24/20", "5/25/20", "5/26/20", "5/27/20", "5/28/20", "5/29/20", "5/30/20", "5/31/20", "6/1/20", "6/2/20", "6/3/20", "6/4/20", "6/5/20", "6/6/20", "6/7/20", "6/8/20", "6/9/20", "6/10/20", "6/11/20", "6/12/20", "6/13/20", "6/14/20", "6/15/20", "6/16/20", "6/17/20", "6/18/20", "6/19/20", "6/20/20"], "y": [510, 606, 879, 1353, 2010, 2784, 5340, 5907, 7920, 9492, 11495, 15953, 18832, 22548, 25947, 28673, 31661, 33698, 36000, 37803, 39006, 38953, 52702, 57304, 57969, 58589, 58807, 58777, 57396, 55773, 55678, 53228, 53095, 51669, 49759, 48192, 46613, 44487, 43244, 42613, 41575, 41407, 40651, 40701, 42437, 43865, 45259, 47056, 49708, 54092, 57673, 69543, 77831, 84520, 96216, 108123, 123989, 148169, 173857, 200037, 224876, 263277, 291558, 332588, 383205, 434968, 490158, 536376, 579676, 636091, 691061, 748545, 809616, 863626, 918476, 967487, 1011135, 1059680, 1112691, 1175880, 1221751, 1295450, 1332638, 1371249, 1406614, 1464509, 1518483, 1562184, 1608859, 1654272, 1686992, 1725709, 1779051, 1810107, 1861491, 1903087, 1939592, 1973827, 2000294, 2014482, 2059461, 2095492, 2138608, 2177168, 2215602, 2255301, 2301154, 2352394, 2379795, 2420683, 2446646, 2487398, 2511300, 2564206, 2608455, 2640890, 2676849, 2708991, 2747895, 2783729, 2834260, 2828535, 2870021, 2908066, 2930142, 2965596, 2999917, 3046504, 3086168, 3140530, 3169317, 3207279, 3211062, 3257536, 3306022, 3365317, 3415826, 3471073, 3419347, 3455563, 3504856, 3552567, 3598068, 3642481, 3701904, 3740224, 3775086, 3827036, 3879898, 3958959, 3961397]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {" ...

# %%
 #Country wise level
country_df.copy().drop(['Lat','Long_','Last_Update','People_Tested','People_Hospitalized','Incident_Rate','ISO3','UID'],axis = 1).sort_values('Confirmed',ascending = False).reset_index(drop = True).style.bar(align = 'left',width = 98)
# Out:
# <style  type="text/css" >
#     #T_f49a74d6_b3da_11ea_b6db_0242ac1c0002row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 98.0%, transparent 98.0%);
#         }    #T_f49a74d6_b3da_11ea_b6db_0242ac1c0002row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 98.0%, transparent 98.0%);
#         }    #T_f49a74d6_b3da_11ea_b6db_0242ac1c0002row0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 98.0%, transparent 98.0%);
#         }    #T_f49a74d6_b3da_11ea_b6db_0242ac1c0002row0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 18.8%, transparent 18.8%);
#         }    #T_f49a74d6_b3da_11ea_b6db_0242ac1c0002row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 44.8%, transparent 44.8%);
#         }    #T_f49a74d6_b3da_11ea_b6db_0242ac1c0002row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 40.9%, transparent 40.9%);
#         }    #T_f49a74d6_b3da_11ea_b6db_0242ac1c0002row1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 27.5%, transparent 27.5%);
#         }    #T_f49a74d6_b3da_11ea_b6db_0242ac1c0002row1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 17.2%, transparent 17.2%);
#         }    #T_f49a74d6_b3da_11ea_b6db_0242ac1c0002row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 25.3%, transparent 25.3%);
#         }    #T_f49a74d6_b3da_11ea_b6db_0242ac1c0002row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 6.6%, transparent 6.6%);
#         }    #T_f49a74d6_b3da_11ea_b6db_0242ac1c0002row2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 16.0%, transparent 16.0%);
#         }    #T_f49a74d6_b3da_11ea_b6db_0242ac1c0002row2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 4.9%, transparent 4.9%);
#         }    #T_f49a74d6_b3da_11ea_b6db_0242ac1c0002row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 17.8%, transparent 17.8%);
#         }    #T_f49a74d6_b3da_11ea_b6db_0242ac1c0002row3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 10.8%, transparent 10.8%);
#         }    #T_f49a74d6_b3da_11ea_b6db_0242ac1c0002row3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 11.5%, transparent 11.5%);
#         }    #T_f49a74d6_b3da_11ea_b6db_0242ac1c0002row3_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 11.5%, transparent 11.5%);
#         }    #T_f49a74d6_b3da_11ea_b6db_0242ac1c0002row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 13.3%, transparent 13.3%);
#         }    #T_f49a74d6_b3da_11ea_b6db_0242ac1c0002row4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 35.0%, transparent 35.0%);
#         }    #T_f49a74d6_b3da_11ea_b6db_0242ac1c0002row4_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 17.7%, transparent 17.7%);
#         }    #T_f49a74d6_b3da_11ea_b6db_0242ac1c0002row4_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 49.7%, transparent 49.7%);
#         }    #T_f49a74d6_b3da_11ea_b6db_0242ac1c0002row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 10.9%, transparent 10.9%);
#         }    #T_f49a74d6_b3da_11ea_b6db_0242ac1c0002row5_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 6.4%, transparent 6.4%);
#         }    #T_f49a74d6_b3da_11ea_b6db_0242ac1c0002row5_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 6.8%, transparent 6.8%);
#         }    #T_f49a74d6_b3da_11ea_b6db_0242ac1c0002row5_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 11.1%, transparent 11.1%);
#         }    #T_f49a74d6_b3da_11ea_b6db_0242ac1c0002row6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 10.7%, transparent 10.7%);
#         }    #T_f49a74d6_b3da_11ea_b6db_0242ac1c0002row6_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 23.2%, transparent 23.2%);
#         }    #T_f49a74d6_b3da_11ea_b6db_0242ac1c0002row6_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 4.5%, transparent 4.5%);
#         }    #T_f49a74d6_b3da_11ea_b6db_0242ac1c0002row6_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 41.0%, transparent 41.0%);
#         }    #T_f49a74d6_b3da_11ea_b6db_0242ac1c0002row7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 10.3%, transparent 10.3%);
#         }    #T_f49a74d6_b3da_11ea_b6db_0242ac1c0002row7_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 28.3%, transparent 28.3%);
#         }    #T_f49a74d6_b3da_11ea_b6db_0242ac1c0002row7_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.4%, transparent 1.4%);
#         }    #T_f49a74d6_b3da_11ea_b6db_0242ac1c0002row7_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 51.7%, transparent 51.7%);
#         }    #T_f49a74d6_b3da_11ea_b6db_0242ac1c0002row8_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 10.3%, transparent 10.3%);
#         }    #T_f49a74d6_b3da_11ea_b6db_0242ac1c0002row8_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.5%, transparent 3.5%);
#         }    #T_f49a74d6_b3da_11ea_b6db_0242ac1c0002row8_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.4%, transparent 2.4%);
#         }    #T_f49a74d6_b3da_11ea_b6db_0242ac1c0002row8_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 6.5%, transparent 6.5%);
#         }    #T_f49a74d6_b3da_11ea_b6db_0242ac1c0002row9_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 8.9%, transparent 8.9%);
#         }    #T_f49a74d6_b3da_11ea_b6db_0242ac1c0002row9_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 7.9%, transparent 7.9%);
#         }    #T_f49a74d6_b3da_11ea_b6db_0242ac1c0002row9_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.1%, transparent 2.1%);
#         }    #T_f49a74d6_b3da_11ea_b6db_0242ac1c0002row9_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 16.7%, transparent 16.7%);
#         }    #T_f49a74d6_b3da_11ea_b6db_0242ac1
